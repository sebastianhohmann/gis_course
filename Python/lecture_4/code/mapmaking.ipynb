# %%
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
import contextily as ctx

# %%
df = gpd.read_file('../lecture_2/data/texas_agsuit.shp')

# %%
df
# Out:
#     NAME_1    NAME_2  mean_suit1  mean_suit2  \
# 0    Texas  Anderson       0.512    0.507833
# 1    Texas   Andrews       0.108    0.099667
# 2    Texas  Angelina       0.230    0.214500
# 3    Texas   Aransas         NaN    0.841000
# 4    Texas    Archer       0.880    0.835250
# ..     ...       ...         ...         ...
# 249  Texas      Wood       0.229    0.425667
# 250  Texas    Yoakum       0.113    0.081000
# 251  Texas     Young       0.717    0.749750
# 252  Texas    Zapata       0.732    0.723000
# 253  Texas    Zavala       0.273    0.395500
#
#                                               geometry
# 0    POLYGON ((-95.27737 31.59311, -95.65746 31.539...
# 1    POLYGON ((-102.28970 32.08851, -102.79818 32.0...
# 2    POLYGON ((-94.55916 31.06005, -94.56059 31.061...
# 3    MULTIPOLYGON (((-96.95293 28.13690, -96.95264 ...
# 4    POLYGON ((-98.42274 33.46517, -98.42251 33.394...
# ..                                                 ...
# 249  POLYGON ((-95.59176 32.68148, -95.59190 32.688...
# 250  POLYGON ((-102.59496 32.95960, -103.01449 32.9...
# 251  POLYGON ((-98.57672 32.95473, -98.95231 32.956...
# 252  POLYGON ((-98.95763 26.78505, -99.00964 26.675...
# 253  POLYGON ((-99.40089 28.64172, -100.11182 28.63...
#
# [254 rows x 5 columns]

# %% [markdown]
# # 1 A simple choropleth

# %%
f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True)
ax.grid()
ax.set_axisbelow(True)
plt.show()

# %% [markdown]
# ## 1.1 Switching off the "frame"

# %%
f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True)
ax.axis('off')
plt.show()

# %% [markdown]
# ## 1.2 Making the plot a large as the colorbar

# %%
f, ax = plt.subplots(1,1, figsize=(5, 5))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=-0.1)
df.plot(ax=ax, 
        cax=cax,
        column='mean_suit2',
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True)
ax.grid()
ax.set_axisbelow(True)
plt.show()

# %% [markdown]
# # 2 Color categories

# %% [markdown]
# note: this requires the mapclassify package to be installed.

# %%
f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True)
ax.grid()
ax.set_axisbelow(True)
plt.show()

# %% [markdown]
# Note the `scheme` argument. We have used `quantiles`. This may not always be the best option. See here for alternatives:
# https://geopandas.org/gallery/choropleths.html

# %% [markdown]
# ## 2.1 Re-positioning the legend

# %%
f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True)
ax.grid()
ax.set_axisbelow(True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.15, 0.8211, 0.2, 0.2))
plt.show()

# %% [markdown]
# ## 2.2 Changing the legend text

# %%
leg.texts
# Out:
# [Text(0, 0, '0.01, 0.14'),
#  Text(0, 0, '0.14, 0.23'),
#  Text(0, 0, '0.23, 0.32'),
#  Text(0, 0, '0.32, 0.42'),
#  Text(0, 0, '0.42, 0.57'),
#  Text(0, 0, '0.57, 0.69'),
#  Text(0, 0, '0.69, 0.77'),
#  Text(0, 0, '0.77, 0.82'),
#  Text(0, 0, '0.82, 0.87'),
#  Text(0, 0, '0.87, 0.95')]

# %%
f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True)
ax.grid()
ax.set_axisbelow(True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.15, 0.8211, 0.2, 0.2))
for txt in leg.texts:
    txti = txt.get_text().replace(', ', ' - ')
    txt.set_text(txti)
plt.show()

# %% [markdown]
# # 3 Dealing with missing data

# %% [markdown]
# Let's artificially introduce some missing data

# %%
for i in range(df.shape[0]):
    if i % 10 == 0:
        df.loc[i, 'mean_suit2'] = np.nan

# %%
f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True)
ax.grid()
ax.set_axisbelow(True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.15, 0.8211, 0.2, 0.2))
for txt in leg.texts:
    txti = txt.get_text().replace(', ', ' - ')
    txt.set_text(txti)
plt.show()

# %% [markdown]
# The counties with missing data are also now missing their outline. We can fix this by adding a `missing_kwds` dictionary to the `plot()` call (this will also add a corresponding entry to the legend)

# %%
missing_kwds = dict(color='white', label='No Data')

f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True, 
        missing_kwds=missing_kwds)
ax.grid()
ax.set_axisbelow(True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.15, 0.8211, 0.2, 0.2))
for txt in leg.texts:
    txti = txt.get_text().replace(', ', ' - ')
    txt.set_text(txti)
plt.show()

# %% [markdown]
# We can also be fancier with our missing values:
# https://geopandas.org/docs/user_guide/mapping.html#missing-data

# %%
missing_kwds = dict(color='lightgrey',
                    edgecolor='red',
                    hatch='///',
                    label='No Data')

f, ax = plt.subplots(1,1, figsize=(5, 5))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True, 
        missing_kwds=missing_kwds)
ax.grid()
ax.set_axisbelow(True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.15, 0.8211, 0.2, 0.2))
for txt in leg.texts:
    txti = txt.get_text().replace(', ', ' - ')
    txt.set_text(txti)
plt.show()

# %% [markdown]
# # 4 Adding a base map

# %% [markdown]
# This follows https://geopandas.org/gallery/plotting_basemap_background.html
#
# For this we need to `conda install contextily`

# %% [markdown]
# Importantly, we need to project our dataframe to Web Mercator, which is the CRS in which web tiles are typically provided.

# %%
df = df.to_crs(epsg=3857)

# %% [markdown]
# ## 4.1 Using OSM as basemap

# %%
missing_kwds = dict(color='white', label='No Data')

f, ax = plt.subplots(1,1, figsize=(10, 10))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True, 
        missing_kwds=missing_kwds,
        alpha=0.7)
ax.grid()
ax.set_axisbelow(True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1, 0.81, 0.2, 0.2))
for txt in leg.texts:
    txti = txt.get_text().replace(', ', ' - ')
    txt.set_text(txti)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
plt.show()

# %% [markdown]
# ## 4.2 Using Stamen Terrain

# %%
missing_kwds = dict(color='white', label='No Data')

f, ax = plt.subplots(1,1, figsize=(10, 10))
df.plot(ax=ax, 
        column='mean_suit2',
        scheme='quantiles',
        k=10,
        cmap='viridis', 
        edgecolor='k',
        linewidth=0.1,
        legend=True, 
        missing_kwds=missing_kwds,
        alpha=0.7)
ax.grid()
ax.set_axisbelow(True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1, 0.81, 0.2, 0.2))
for txt in leg.texts:
    txti = txt.get_text().replace(', ', ' - ')
    txt.set_text(txti)
ctx.add_basemap(ax, source=ctx.providers.Stamen.Terrain)
plt.show()
